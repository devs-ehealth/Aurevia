# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import re

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Load Dataset    -   GoEmotions  (Text)

# %%
data1 = pd.read_csv(r"D:\Aurevia\data\raw\GoEmotions\goemotions_1.csv")
data2 = pd.read_csv(r"D:\Aurevia\data\raw\GoEmotions\goemotions_2.csv")
data3 = pd.read_csv(r"D:\Aurevia\data\raw\GoEmotions\goemotions_3.csv")

# %% [markdown]
# Me
